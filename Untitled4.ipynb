# %% [markdown]
# <a href="https://colab.research.google.com/github/minji25-hue/ABCD-A/blob/20250403/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
t = float(input("공이 떨어지기까지 걸린 시간(s)을 입력하세요: "));
x = float(input("수평 거리(m)를 입력하세요: "))
g = 9.81;
a = -g; #중력가속도는 -y방향으로 작용
y0 = 0;
v0y = 0;

#a 공의 처음속도 >> 2초에 20m을 움직임 >> x/t = 10m/s
v0x = x/t
#b 옥상의 높이 >> 2초 후에 공이 지면에 닿음 >> y = y0 + v0t + 1/2at^2 >> y = 0m + 0 * 2s + 1/2(-9.81m/s^2*4s^2) >> y = 0m + 0 + 1/2(-9.81m*4) = 19.62m
y = y0 + v0y*t + 1/2*g*t*t;
#c 공이 지면에 닿을 때의 속도 >> vx = 초기속도 = v0x = 10m/s, vy = v0y + at >> vy = 0*y(=19.62m) + (-9.81m/s^2)*2s = -19.62m/s
vx = v0x;
vy = v0y + g * t;

 # 최종 속도 크기 >> 루트({vx}^2 + {vy}^2)
v = math.sqrt(vx*vx + vy*vy);

theta_rad = math.atan(vy/vx);
theta_deg = math.degrees(theta_rad);

print(f"\n[결과]")

print(f"a) 공의 처음속도 크기: {v0x:.2f} m/s") # v0x를 사용했으므로 v0 > v0x로 교체

print(f"b) 건물 높이: {y:.2f} m")

print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")

print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")5
# Out:
# 공이 떨어지기까지 걸린 시간(s)을 입력하세요: 5
# 수평 거리(m)를 입력하세요: 2
#
# [결과]
# a) 공의 처음속도 크기: 0.40 m/s
# b) 건물 높이: 122.63 m
# c) 충돌 순간 속도 크기: 49.05 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): 89.53도
