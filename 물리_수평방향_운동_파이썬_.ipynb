# %% [markdown]
# <a href="https://colab.research.google.com/github/minji25-hue/ABCD-A/blob/20250403/%EB%AC%BC%EB%A6%AC_%EC%88%98%ED%8F%89%EB%B0%A9%ED%96%A5_%EC%9A%B4%EB%8F%99_%ED%8C%8C%EC%9D%B4%EC%8D%AC_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

t = float(input("공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): "))

x = float(input("수평 거리 (m)를 입력하세요 (예: 20): "))

g = -9.81  # m/s^2

v0 = x / t

y = (g * t**2)/2

vx = v0
vy = g * t

v = math.sqrt(vx*vx+vy*vy)


theta_rad = math.atan(vy/vx)

theta_deg =math.degrees(theta_rad)


print(f"\n[결과]")

print(f"a) 공의 처음속도 크기: {v0:.2f} m/s")

print(f"b) 건물 높이: {y:.2f} m")

print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")

print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# 공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): 2
# 수평 거리 (m)를 입력하세요 (예: 20): 20
#
# [결과]
# a) 공의 처음속도 크기: 10.00 m/s
# b) 건물 높이: -19.62 m
# c) 충돌 순간 속도 크기: 22.02 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): -62.99도
