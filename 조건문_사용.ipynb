# %% [markdown]
# <a href="https://colab.research.google.com/github/minji25-hue/ABCD-A/blob/20250329/%EC%A1%B0%EA%B1%B4%EB%AC%B8_%EC%82%AC%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "tset"
if name == "test":
  print("이름이 맞습니다.")
else:
  print("이름이 다릅니다.")
# Out:
# 이름이 다릅니다.

# %%
#if elif else 예제
pocket=1000
if pocket == 1000:
  print("복권 구매")
elif pocket == 500:
  print("껌 구매")
else:
  print("집")
# Out:
# 복권 구매

# %%
a="사과"
b="바나나"
c="치즈"
if a == "사과" or b == "안바나나": #true
  print("사과 이거나 바나나 입니다.")
if a== "사과" and b == "바나나": #ture
  print("사과 이고 바나나 입니다.")
if not a == "사과": #a가 사과인데 not 이므로 false
  print("사과가 아니어야 여기 들어옵니다.")
# Out:
# 사과 이거나 바나나 입니다.
# 사과 이고 바나나 입니다.

# %%
a=[1,2,3,4,5,6,7,8]
if 1 in a:
  print("a 리스트에 1이 포함되어있습니다.")
elif 10 in a:
  print("a리스트에 10이 포함되어 있습니다.")
# Out:
# a 리스트에 1이 포함되어있습니다.
